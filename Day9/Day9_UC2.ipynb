# %%
from lxml import html
import requests

page = requests.get('https://gulfnews.com/search?query=etisalat')
tree = html.fromstring(page.content)
page.content
# Out:
# b'<!doctype html>\n<html lang="en">\n    <head>\n        <!-- Required meta tags -->\n        <meta charset="utf-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n        <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,800,900" rel="stylesheet">\n        <link rel="icon" type="image/png" href="https://assets.gulfnews.com/images/icons/favicon-96x96.png" sizes="96x96">\n        <link rel="icon" type="image/png" href="https://assets.gulfnews.com/images/icons/favicon-32x32.png" sizes="32x32">\n        <link rel="icon" type="image/png" href="https://assets.gulfnews.com/images/icons/favicon-16x16.png" sizes="16x16">\n        <link rel="icon" href="https://assets.gulfnews.com/images/icons/favicon.ico" type="image/x-icon">\n        <link rel="prefetch" href="//gulfnews.com/svg/gn-sprite.svg">\n<link href="https://assets.gulfnews.com/css/main.c3c94f19ea7f40effa1a.css" rel="stylesheet">\n<script src="https://asse
# ...

# %%
tree
# Out:
# <Element html at 0x22d57527c78>

# %%
etisal = tree.xpath('/html/body/div[6]/div[4]/div/div/div[2]/div/div/div[1]/div[2]/div[1]/div/div/div[1]/a/')
print (etisal)
for tag in etisal:
    print(tag.text_content())
    print(tag.tag)
    print(tag.get('href'))
# Out:
# ---------------------------------------------------------------------------
# XPathEvalError                            Traceback (most recent call last)
# <ipython-input-5-3bb0f8824000> in <module>
# ----> 1 etisal = tree.xpath('/html/body/div[6]/div[4]/div/div/div[2]/div/div/div[1]/div[2]/div[1]/div/div/div[1]/a/')
#       2 print (etisal)
#       3 for tag in etisal:
#       4     print(tag.text_content())
#       5     print(tag.tag)
#
# src/lxml/etree.pyx in lxml.etree._Element.xpath()
#
# src/lxml/xpath.pxi in lxml.etree.XPathElementEvaluator.__call__()
#
# src/lxml/xpath.pxi in lxml.etree._XPathEvaluatorBase._handle_result()
#
# XPathEvalError: Invalid expression
